# %%
import pandas as pd

# %%
path = "C:/Users/User/Desktop/encoded-BD01050122W_Prosenjit_2024-09-04_02-15-12PM.csv"
import csv

df1 = pd.read_csv(path,sep=',',quoting=csv.QUOTE_ALL,skipinitialspace=True)

# %%
df.head()
# Out:
#   WorksOrderno,SizeHeader1,SizeHeader2,SizeHeader3,SizeHeader4,SizeHeader5,SizeDetail1,SizeDetail2,SizeDetail3,SizeDetail4,SizeDetail5,CopyrightID,CautionID,CuttingID,Season,Printerid,Multipartset-descr,Multipartset-descr-2,FabricQualityID,Width,Length,Specialreq,CareCodeID,Prtcolour1,Prtcolour2,Prtcolour3,Prtcolour4,Prtcolour5,Prtcolour6,Backcolour1,Backcolour2,Pantone_ref1,Pantone_ref2,Pantone_ref3,Pantone_ref4,Pantone_ref5,Pantone_ref6,Pantone_ref7,Pantone_ref8,Symbol1,Symbol2,Symbol3,Symbol4,Symbol5,Symbol6,Symbol7,Symbol8,Styleno,SizeID,ProductID,CustOrderNo,CustNo,Cust_Name,QtyOrdered,Deliverydate,Delivery-address,Orderdate,Label_price,Custproduct,Item_number,Colour,Label_pack_code,Rn,Ca,Omnix-product,Packsize,Pairs,Ponumber,Styleid,Factorycode,Datecode,SizeHeader-translations1,SizeHeader-translations2,SizeHeader-translations3,SizeHeader-translations4,SizeHeader-translations5,SizeHeader-translations6,SizeHeader-translations7,SizeHeader-translations8,SizeHeader-translations9,Siz
# ...

# %%
import pandas as pd

path='cleaned_file.csv'
# Read the CSV file, treating quotes as regular data
df = pd.read_csv(path, quoting=3, encoding='utf-8' )

# # Save the cleaned data to a new CSV file without quoting
# df.to_csv('cleaned_file.csv', index=False, quoting=3)

# %%
df.columns
# Out:
# Index(['"WorksOrderno', 'SizeHeader1', 'SizeHeader2', 'SizeHeader3',
#        'SizeHeader4', 'SizeHeader5', 'SizeDetail1', 'SizeDetail2',
#        'SizeDetail3', 'SizeDetail4',
#        ...
#        'Field991', 'Field992', 'Field993', 'Field994', 'Field995', 'Field996',
#        'Field997', 'Field998', 'Field999', 'Field1000"'],
#       dtype='object', length=1000)

# %%
# Remove quotes from all columns
df = df.replace({'"': '', "'": ''}, regex=True)

# Save the cleaned data to a new CSV file
df.to_csv('cleaned_file.csv', index=False, quoting=3)

# %%
df
# Out:
#                                                                                                                                         "WorksOrderno  \
# "BD01050122W ""SIZE"" ""height/weight"" ""weight"" """" """" ""3-6mths""   ""weight 8kg/18lbs""  ""height 68cm"" """" """" """" ""B11""
#                                                              ""6-9mths""   ""weight 9½kg/21lbs"" ""height 74cm"" """" """" """" ""B11""
#                                                              ""9-12mths""  ""weight 11kg/24lbs"" ""height 80cm"" """" """" """" ""B11""
#                                                              ""12-18mths"" ""height 86cm""       """"            """" """" """" ""B11""
#                                                              ""1½-2yrs""   ""height 92cm""       """"            """" """" """" ""B11""
#                                                              ""2-3yrs""    ""height 98cm""       """"            """" """" """" ""B11""
# ...
